# %%
name = "Sagar Chandrakant Pujari"
print(name[0:5])
print(name[6:17])
print(name[18:24])
print(name[-1: :-1])
print(len(name))
print(name[ : :2])
print(name[ : :-2])
print(name[ : :-1])
print(name[ : :-3])
print(name[ : :])
print(name[ : :-4])
print(name[ : :-5])
print(name[ : :-6])
print(name[ : :-7])
print(name[0: :-8])
print(name[0:20+5:1])
print(name[-1:-341:-1])
print(name[-1:+324-231566:-1])
print(name[0: :])
# Out:
# Sagar
# Chandrakant
# Pujari
# irajuP tnakardnahC ragaS
# 24
# SgrCadaatPjr
# iau nkrnh aa
# irajuP tnakardnahC ragaS
# ij ara g
# Sagar Chandrakant Pujari
# iunrha
# iPkaa
# i r
# itng
# S
# Sagar Chandrakant Pujari
# irajuP tnakardnahC ragaS
# irajuP tnakardnahC ragaS
# Sagar Chandrakant Pujari
